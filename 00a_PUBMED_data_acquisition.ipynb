# %% [markdown]
# # Pubmed data acquisition and munging
# - Download pubmed data and convert it into a handy csv.
#
# ## Note on downloading PubMed data.
# The easiest way I have found to do this, is to simply download everything from here: ftp://ftp.ncbi.nlm.nih.gov/pubmed/baseline
#
# - Windows: use Windows Subsystem for Linux (WSL)
# - Mac/Linux: just use a terminal.
#
# Replace 'destinationPath' with the path to an empty directory where you want to download the data to. In my case, this was `D:\pubmed\data`
#
# `wget ftp://ftp.ncbi.nlm.nih.gov/pubmed/baseline/* destinationPath`
#
# This will take a while to complete. On my connection, it took around 1 day.

# %%
import os
import gzip
from bs4 import BeautifulSoup as bs
import glob
import pandas as pd
import datetime

# %% [markdown]
# How many files are there? Get all of the filepaths and store in an object 'filepaths'

# %%
working_data_path = r'C:\Users\aday\OneDrive - SAGE Publishing\PROJECT_DATA\pubmed_case_report_classifier\data'

# %%
pubmed_data_path = r'C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed'
p = os.path.abspath(os.path.join(pubmed_data_path,'*'))
filepaths = glob.glob(p)
filepaths = [ x for x in filepaths if x.endswith('.xml.gz')]
len(filepaths)
# Out:
# 1062

# %% [markdown]
# Flip the ordering of filepaths. This means that we start with recent stuff and work our way backwards in time.

# %%
filepaths = filepaths[::-1]
len(filepaths)
# Out:
# 1062

# %% [markdown]
# Now iterate over the files and pull out all of the data from the 'years_of_interest'. When we reach a file which no longer has data from these years, we can stop.

# %% [markdown]
# # Create a class for handling pubmed XML

# %%
import datetime
from bs4 import BeautifulSoup as bs
import pandas as pd

class PubMedDataSet:
    
    def __init__(self, years_of_interest:set):
        self.years_of_interest = years_of_interest
    
    def process_files(self, filepaths):
        
        years_in_file = set()
        years_of_interest = self.years_of_interest

        dataframe_path = os.path.join(working_data_path,'pubmed_sample.csv')
        
        if os.path.exists(dataframe_path):
            df = pd.read_csv(dataframe_path)
        else:
            df = pd.DataFrame()
            
        for filepath in filepaths:
            try:
                print(datetime.datetime.now(), '| Processing:', filepath)
                if len(list(years_in_file))>0:
                    # recall that we are reading our files in reverse-chronological order.
                    # they contain lots of years-worth of data, but older files should not have recent years
                    # this says 'if NONE of our years of interest were in the last file, 
                    # then we assume that we are looking at older data now and we stop reading
                    # the files. 
                    if not any([(x in years_of_interest) for x in list(years_in_file) ]):
                        print('Breaking loop - we are no longer looking at our years of interest.')
                        break
                years_in_file = set()
                rows = self.process_file(filepath)
                data = []
                for row in rows:
                    years_in_file.add(row['year'])
                    data.append(row)
                print(len(data), 'rows found. Years in file:', years_in_file)
                new_rows = pd.DataFrame(data)
                n_rows_found = new_rows[new_rows['year'].isin(years_of_interest)].shape[0]
                df = pd.concat([df,new_rows])
                df = df[df['year'].isin(years_of_interest)]
                print(datetime.datetime.now(),'| File complete. DataFrame shape:', df.shape)
                print()
                df.to_csv(dataframe_path, index=False, encoding = 'utf-8-sig')
                n_rows_cutoff = 500
                if n_rows_found <n_rows_cutoff:
                    print(f'BREAKING loop - fewer than {n_rows_cutoff} rows found in last file.')
            except Exception as e:
                print('Failure for ', filepath)
                print(e)
        return df
    

    def process_file(self, filepath):
        with gzip.open(filepath) as f:
            # TODO - soup is slow, switch to etree
            soup = bs(f.read(),'lxml')
        articles = self.get_articles(soup)
        for article in articles:
            row = self.build_row(article)
            yield row


    def build_row(self, article):
        articledate, reviseddate = self.get_article_dates(article)
        doi, pii, pmid, pmc = self.get_article_ids(article)
        journal_title, journal_issn, journal_iso = self.get_journal_dets(article)
        article_type1, article_type2, article_type3 = self.get_art_types(article)
        row = {'title':self.get_title(article),
              'articletitle':self.get_article_title(article),
              'abstract':self.get_abstract(article),
              'year':self.get_year(article),
              'articledate':articledate,
              'doi':doi,
              'pmid':pmid,
              'pii':pii,
              'pmc':pmc,
               'articletype1' :article_type1 ,
                'articletype2' :article_type2,
                'articletype3':article_type3,
               'journal_title':journal_title,
               'journal_issn':journal_issn,
               'journal_iso':journal_iso,
              }
        return row

    def get_year(self, article):
        year = None
        try:
            year = article.pubdate.year.text
        except:
            pass
        return year


    def get_articles(self, soup):
        articles = soup.find_all('pubmedarticle')
        return articles

    def get_art_types(self, article):
        article_type1 = None
        article_type2 = None
        article_type3 = None

        try:
            art_types = [x.attrs['ui']+'|'+x.text for x in article.find_all('publicationtype')]
            try:
                article_type1 = art_types[0]
            except:
                pass
            try:
                article_type2 = art_types[1]
            except:
                pass
            try:
                article_type3 = art_types[2]
            except:
                pass
        except:
            pass
        return article_type1, article_type2, article_type3

    def get_article_title(self, article):
        articletitle = None
        try:
            articletitle = article.articletitle.text
        except:
            pass
        return articletitle


    def get_title(self, article):
        title = None
        try:
            title = article.title.text
        except:
            pass
        return title

    def get_abstract(self, article):
        abstract = None
        try:
            abstract = ' '.join([x.text for x in article.abstract.find_all('abstracttext')])
        except:
            pass
        return abstract

    def get_article_dates(self, article):
        articledate = None
        reviseddate = None
        try:
            reviseddate = article.daterevised.year.text+'-'+article.daterevised.month.text+'-'+article.daterevised.day.text
        except:
            pass
        try:
            articledate = article.articledate.year.text+'-'+article.articledate.month.text+'-'+article.articledate.day.text
        except:
            pass
        return articledate, reviseddate

    def get_article_ids(self, article):
        doi = None
        pii = None
        pmid = None
        pmc = None
        try:
            ids = {x.attrs['idtype']: x.text  for x in article.find_all('articleid')}
            try:
                doi = ids['doi']
            except:
                pass
            try:
                pmid = article.pmid.text
            except:
                try:
                    pmid = ids['pmid']
                except:
                    pass
            try:
                pii = ids['pii']
            except:
                pass
            try:
                pmc = ids['pmc']
            except:
                pass
        except:
            pass
        return doi, pii, pmid, pmc

    def get_journal_dets(self, article):
        journal_title = None
        journal_issn = None
        journal_iso = None
        try:
            journal = article.journal
            try:
                journal_iso = journal.isoabbreviation.text
            except:
                pass
            try:
                journal_issn = journal.issn.text
            except:
                pass
            try:
                journal_title = journal.title.text
            except:
                pass

        except:
            pass
        return journal_title, journal_issn, journal_iso

# %% [markdown]
# ### Example XML
# (requires reading a whole file into memory, so it's a bit slow!)

# %%
# %%time
# filepath = filepaths[0]
# with gzip.open(filepath) as f:
#     # TODO - soup is slow, switch to etree?
#     soup = bs(f.read(),'lxml')
# articles = soup.find_all('pubmedarticle')
# articles[0]

# %%
years_of_interest = {'2021','2020','2019','2018'}
df = PubMedDataSet(years_of_interest = years_of_interest).process_files(filepaths)
df.shape
# Out:
# 2021-04-09 12:42:58.565573 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1062.xml.gz
# 20051 rows found. Years in file: {'2012', None, '2021', '2018', '2000', '2019', '2010', '2020', '2007', '2008', '1986', '2016', '2017', '2003', '2015', '1993', '1998', '2014', '1997', '2006', '2005', '2011'}
# 2021-04-09 12:45:30.575564 | File complete. DataFrame shape: (19547, 15)
#
# 2021-04-09 12:45:32.007050 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1061.xml.gz
# 30000 rows found. Years in file: {'2006', None, '2021', '2018', '2017', '2000', '2019', '2020'}
# 2021-04-09 12:48:57.586595 | File complete. DataFrame shape: (48541, 15)
#
# 2021-04-09 12:48:59.390604 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1060.xml.gz
# 30000 rows found. Years in file: {'2016', '2013', None, '2021', '2018', '2017', '2019', '2020', '1999', '2015'}
# 2021-04-09 12:52:42.993298 | File complete. DataFrame shape: (77933, 15)
#
# 2021-04-09 12:52:45.812907 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1059.xml.gz
# 30000 rows found. Years in file: {'2016', '2013', None, '2021', '2018', '2009', '2017', '2019', '2020', '2015'}
# 2021-04-09 12:56:19.919591 | File complete. DataFrame shape: (107340, 15)
#
# 2021-04-09 12:56:23.851607 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1058.xml.gz
# 30000 rows found. Years in file: {'2016', None, '2021', '2018', '1982', '2017', '2000', '2019', '2020', '2015', '2011'}
# 2021-04-09 13:00:32.161902 | File complete. DataFrame shape: (136909, 15)
#
# 2021-04-09 13:00:37.712926 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1057.xml.gz
# 30000 rows found. Years in file: {'2014', '2002', '2016', None, '2021', '2018', '1982', '2017', '2009', '2019', '2020', '1999', '2015'}
# 2021-04-09 13:04:31.489929 | File complete. DataFrame shape: (165676, 15)
#
# 2021-04-09 13:04:37.850340 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1056.xml.gz
# 30000 rows found. Years in file: {'2012', '2016', '2008', '2013', None, '2021', '2018', '2017', '2019', '2010', '2020', '2015', '2011'}
# 2021-04-09 13:08:24.710258 | File complete. DataFrame shape: (194917, 15)
#
# 2021-04-09 13:08:32.012287 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1055.xml.gz
# 30000 rows found. Years in file: {'2014', '2016', '2013', None, '2021', '2018', '2017', '2019', '2020', '2015'}
# 2021-04-09 13:12:24.993235 | File complete. DataFrame shape: (223887, 15)
#
# 2021-04-09 13:12:33.445301 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1054.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2008', '2016', None, '2021', '2018', '2017', '2019', '2003', '2010', '1992', '2020', '2015'}
# 2021-04-09 13:16:20.172465 | File complete. DataFrame shape: (253267, 15)
#
# 2021-04-09 13:16:29.524465 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1053.xml.gz
# 30000 rows found. Years in file: {'2012', '1997', '2016', '2013', None, '2021', '2018', '2017', '2019', '2020', '1994'}
# 2021-04-09 13:20:13.751957 | File complete. DataFrame shape: (282649, 15)
#
# 2021-04-09 13:20:24.413995 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1052.xml.gz
# 30000 rows found. Years in file: {'2012', '1985', '2016', '1984', '2013', None, '2021', '2018', '1982', '2017', '2019', '1983', '2020', '1981', '2015', '2011'}
# 2021-04-09 13:24:28.638464 | File complete. DataFrame shape: (311457, 15)
#
# 2021-04-09 13:24:40.354689 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1051.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', None, '2021', '1996', '2018', '2017', '2019', '2020', '1994', '2015', '2011'}
# 2021-04-09 13:28:39.385903 | File complete. DataFrame shape: (340742, 15)
#
# 2021-04-09 13:28:52.551946 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1050.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2013', '2016', None, '2021', '2018', '2017', '2009', '2019', '2020', '1999', '2015', '2011'}
# 2021-04-09 13:32:36.373676 | File complete. DataFrame shape: (369811, 15)
#
# 2021-04-09 13:32:49.899679 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1049.xml.gz
# 30000 rows found. Years in file: {'2012', '1985', None, '2021', '2018', '2019', '2020', '2007', '2016', '2008', '1986', '2017', '2015', '2013', '1980', '2014', '2006', '1989', '1977', '2009'}
# 2021-04-09 13:36:42.277355 | File complete. DataFrame shape: (398677, 15)
#
# 2021-04-09 13:36:57.060379 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1048.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', '1988', None, '2021', '2018', '2017', '2019', '2020', '2015'}
# 2021-04-09 13:40:43.307071 | File complete. DataFrame shape: (427554, 15)
#
# 2021-04-09 13:40:59.173112 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1047.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '2019', '1990', '1983', '2010', '2020', '1999', '2007', '2016', '2008', '1995', '2017', '2003', '2015', '2013', '1993', '2014', '2006', '2009', '2004', '2011'}
# 2021-04-09 13:44:57.926789 | File complete. DataFrame shape: (456181, 15)
#
# 2021-04-09 13:45:14.747829 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1046.xml.gz
# 30000 rows found. Years in file: {'2012', '2007', '2006', '2016', '2008', None, '2021', '1996', '2018', '2017', '2009', '2019', '2010', '2020', '2005', '2015'}
# 2021-04-09 13:49:05.448471 | File complete. DataFrame shape: (485198, 15)
#
# 2021-04-09 13:49:23.592774 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1045.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2013', '2016', None, '2021', '2018', '2009', '2017', '2019', '2010', '1979', '2003', '2020', '2004', '2015', '2011'}
# 2021-04-09 13:53:12.298382 | File complete. DataFrame shape: (514178, 15)
#
# 2021-04-09 13:53:31.212435 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1044.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2016', '2013', None, '2021', '2018', '2017', '2019', '2020', '2015'}
# 2021-04-09 13:57:24.974034 | File complete. DataFrame shape: (543167, 15)
#
# 2021-04-09 13:57:45.145086 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1043.xml.gz
# 30000 rows found. Years in file: {'2012', '2007', '2006', '2016', '2013', '1986', '1989', None, '2021', '1985', '2018', '2017', '2019', '2020', '2015', '2011'}
# 2021-04-09 14:01:41.738267 | File complete. DataFrame shape: (572182, 15)
#
# 2021-04-09 14:02:02.867333 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1042.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2021', '2018', '2000', '2019', '2010', '2020', '2007', '2016', '2008', '2017', '2003', '2015', '2013', '2006', '1996', '2009', '2005', '2004', '2011'}
# 2021-04-09 14:05:54.295013 | File complete. DataFrame shape: (599847, 15)
#
# 2021-04-09 14:06:16.180060 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1041.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', None, '2021', '2018', '2017', '2019', '2010', '2020', '1991', '2015'}
# 2021-04-09 14:10:16.491772 | File complete. DataFrame shape: (628765, 15)
#
# 2021-04-09 14:10:40.108816 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1040.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2006', '2016', '2008', None, '2021', '2015', '2018', '2017', '2019', '2010', '2020', '2005', '1981', '2011'}
# 2021-04-09 14:14:45.888421 | File complete. DataFrame shape: (657136, 15)
#
# 2021-04-09 14:15:10.154470 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1039.xml.gz
# 30000 rows found. Years in file: {'2016', None, '2021', '2018', '2017', '2019', '2020', '2015', '2011'}
# 2021-04-09 14:18:56.142001 | File complete. DataFrame shape: (686007, 15)
#
# 2021-04-09 14:19:21.576263 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1038.xml.gz
# 30000 rows found. Years in file: {'2014', '2007', '2006', '2008', '2016', '2013', None, '2021', '2018', '2009', '2017', '2019', '2020', '2005', '1999', '2004', '2015', '2011'}
# 2021-04-09 14:23:23.114807 | File complete. DataFrame shape: (715052, 15)
#
# 2021-04-09 14:23:49.708836 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1037.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2016', '2013', None, '2021', '2018', '2017', '2019', '2003', '1992', '2020', '2005'}
# 2021-04-09 14:27:42.488380 | File complete. DataFrame shape: (744226, 15)
#
# 2021-04-09 14:28:09.540430 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1036.xml.gz
# 30000 rows found. Years in file: {'2014', '2007', '2006', '2008', '2013', '2016', None, '2021', '2018', '2017', '2009', '2019', '2010', '2020', '2005', '2015'}
# 2021-04-09 14:32:02.902344 | File complete. DataFrame shape: (773142, 15)
#
# 2021-04-09 14:32:31.601363 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1035.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', None, '2021', '2018', '2017', '2009', '2019', '2010', '2020', '2015', '2011'}
# 2021-04-09 14:36:19.817748 | File complete. DataFrame shape: (800996, 15)
#
# 2021-04-09 14:36:49.427050 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1034.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2006', '2016', '2013', None, '2021', '2018', '2017', '2009', '2019', '2020', '1994', '2015', '2011'}
# 2021-04-09 14:40:49.943631 | File complete. DataFrame shape: (829929, 15)
#
# 2021-04-09 14:41:20.480735 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1033.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1033.xml.gz
# Error -3 while decompressing data: invalid block type
# 2021-04-09 14:41:20.560782 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1032.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2021', '2018', '2000', '2019', '1983', '2010', '2020', '2007', '2008', '2016', '2017', '2003', '2015', '1976', '2013', '1993', '1987', '2014', '1996', '2009', '2005', '1994', '2011', '1974'}
# 2021-04-09 14:45:21.934209 | File complete. DataFrame shape: (859126, 15)
#
# 2021-04-09 14:45:54.178673 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1031.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '2019', '1990', '2010', '1992', '2020', '1988', '2007', '2016', '2008', '1986', '2017', '2003', '1991', '2015', '2013', '1993', '1987', '2014', '1997', '2006', '1989', '2009', '2005', '1994', '2004', '2011'}
# 2021-04-09 14:50:03.655011 | File complete. DataFrame shape: (887691, 15)
#
# 2021-04-09 14:50:36.984618 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1030.xml.gz
# 30000 rows found. Years in file: {'2012', '1985', '2002', None, '2021', '2018', '1982', '2000', '1967', '2019', '1990', '2010', '1992', '1983', '2020', '1999', '1988', '2007', '2008', '2016', '1986', '1995', '2017', '2003', '1991', '2015', '2013', '1984', '1993', '1979', '1998', '1987', '1980', '2014', '1997', '2006', '1989', '1996', '1977', '2001', '2009', '1973', '2005', '1994', '2004', '2011'}
# 2021-04-09 14:54:34.969085 | File complete. DataFrame shape: (916448, 15)
#
# 2021-04-09 14:55:08.481152 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1029.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1029.xml.gz
# Error -3 while decompressing data: invalid block type
# 2021-04-09 14:55:08.531163 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1028.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '2019', '2010', '2020', '1999', '2007', '2008', '2016', '2017', '2015', '2013', '2014', '2006', '2009', '2005', '2004', '2011'}
# 2021-04-09 14:59:01.839537 | File complete. DataFrame shape: (941219, 15)
#
# 2021-04-09 14:59:36.331634 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1027.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2021', '2018', '2000', '2019', '2010', '1983', '1992', '1990', '2020', '1999', '1988', '2007', '2016', '2008', '1986', '1995', '2017', '2003', '2015', '2013', '1956', '2014', '1997', '2006', '1996', '2001', '2009', '2005', '2004', '2011'}
# 2021-04-09 15:03:24.019022 | File complete. DataFrame shape: (970017, 15)
#
# 2021-04-09 15:03:59.163130 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1026.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2021', '2018', '1982', '2000', '2019', '2010', '2020', '1988', '2007', '2016', '2008', '1986', '2017', '2003', '1991', '2015', '2013', '1978', '1979', '2014', '2006', '1989', '1977', '2001', '2009', '1973', '2005', '2004', '1981', '2011'}
# 2021-04-09 15:08:06.566494 | File complete. DataFrame shape: (998480, 15)
#
# 2021-04-09 15:08:42.847756 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1025.xml.gz
# 30000 rows found. Years in file: {'2012', '1997', '2002', '2016', '1984', None, '1996', '2021', '2018', '1982', '2017', '2019', '1998', '2020', '2015', '2011'}
# 2021-04-09 15:12:47.368220 | File complete. DataFrame shape: (1027063, 15)
#
# 2021-04-09 15:13:25.327235 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1024.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2021', '2018', '2019', '1990', '1992', '2020', '2016', '2008', '2017', '2003', '1991', '2015', '2013', '1984', '1993', '1997', '2001', '1994', '2011'}
# 2021-04-09 15:17:32.528675 | File complete. DataFrame shape: (1055780, 15)
#
# 2021-04-09 15:18:11.425698 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1023.xml.gz
# 30000 rows found. Years in file: {'2014', '1985', '2012', '2016', '1984', None, '2021', '2018', '2017', '2019', '2010', '2020', '2015'}
# 2021-04-09 15:22:21.867569 | File complete. DataFrame shape: (1084579, 15)
#
# 2021-04-09 15:23:03.554074 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1022.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', None, '2021', '1996', '2018', '2015', '2017', '2009', '2019', '1993', '1990', '2020', '1994', '1988'}
# 2021-04-09 15:27:06.936756 | File complete. DataFrame shape: (1113177, 15)
#
# 2021-04-09 15:27:47.855559 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1021.xml.gz
# 30000 rows found. Years in file: {'2014', '2016', '2013', '2008', None, '2021', '2018', '2001', '2017', '2009', '2019', '2020', '2015'}
# 2021-04-09 15:32:02.974950 | File complete. DataFrame shape: (1142010, 15)
#
# 2021-04-09 15:32:45.194290 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1020.xml.gz
# 30000 rows found. Years in file: {'2014', '2007', '2002', '2016', '2013', '2006', None, '2021', '2018', '2001', '1995', '2017', '2019', '2020', '2015'}
# 2021-04-09 15:37:08.821007 | File complete. DataFrame shape: (1170492, 15)
#
# 2021-04-09 15:37:52.736332 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1019.xml.gz
# 30000 rows found. Years in file: {'2012', '1985', None, '2021', '2018', '1982', '2019', '1983', '2020', '1999', '1988', '2016', '1986', '2017', '2015', '2013', '1984', '1987', '2014', '1981'}
# 2021-04-09 15:42:31.519124 | File complete. DataFrame shape: (1198043, 15)
#
# 2021-04-09 15:43:16.762685 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1018.xml.gz
# 30000 rows found. Years in file: {'2014', '1997', '2013', '2016', '1989', '1988', None, '2021', '1996', '2018', '2017', '1993', '2019', '1990', '1992', '2020', '1991', '2015'}
# 2021-04-09 15:47:40.686968 | File complete. DataFrame shape: (1225497, 15)
#
# 2021-04-09 15:48:25.523471 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1017.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '2019', '2010', '2020', '2016', '2008', '1995', '2017', '2015', '2013', '1993', '2014', '1997', '1996', '2009', '1994'}
# 2021-04-09 15:52:54.806255 | File complete. DataFrame shape: (1254044, 15)
#
# 2021-04-09 15:53:43.725974 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1016.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2021', '2018', '2019', '1990', '2020', '1999', '2016', '2008', '2017', '2003', '1972', '1987', '2014', '1997', '1994', '2004'}
# 2021-04-09 15:58:09.362005 | File complete. DataFrame shape: (1282564, 15)
#
# 2021-04-09 15:59:01.136817 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1015.xml.gz
# 30000 rows found. Years in file: {'2012', '2016', None, '2021', '1996', '2018', '2017', '2019', '1983', '1992', '2020', '2015'}
# 2021-04-09 16:03:21.814151 | File complete. DataFrame shape: (1311478, 15)
#
# 2021-04-09 16:04:14.151353 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1014.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2021', '2018', '2000', '2019', '2010', '1992', '2020', '1999', '2016', '1995', '2017', '2015', '1993', '1987', '2014', '2001', '2009', '2005', '2004'}
# 2021-04-09 16:08:37.148190 | File complete. DataFrame shape: (1340321, 15)
#
# 2021-04-09 16:09:27.382265 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1013.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2021', '2018', '2019', '2010', '2020', '2016', '1995', '2017', '2015', '1976', '2013', '1980', '2014', '1996', '1994', '2011'}
# 2021-04-09 16:13:54.079611 | File complete. DataFrame shape: (1368850, 15)
#
# 2021-04-09 16:14:44.129033 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1012.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2006', '2008', '2016', '2013', None, '2021', '2018', '2017', '2009', '2019', '2020', '2005', '2015', '2011'}
# 2021-04-09 16:19:02.800953 | File complete. DataFrame shape: (1397824, 15)
#
# 2021-04-09 16:19:57.950340 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1011.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2002', '2016', '2013', None, '2021', '2018', '2017', '2009', '2019', '2003', '2020', '2015', '2011'}
# 2021-04-09 16:24:26.616344 | File complete. DataFrame shape: (1426660, 15)
#
# 2021-04-09 16:25:19.512829 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1010.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2021', '2018', '2000', '2019', '2010', '2020', '2007', '2016', '2008', '2017', '2003', '2015', '2013', '2014', '2006', '2001', '2009', '2005', '2004', '2011'}
# 2021-04-09 16:29:35.478958 | File complete. DataFrame shape: (1455273, 15)
#
# 2021-04-09 16:30:30.286998 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1009.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2013', '2016', '2008', None, '2021', '1996', '2018', '2017', '2019', '2010', '2020', '2015', '2011'}
# 2021-04-09 16:34:42.906147 | File complete. DataFrame shape: (1484129, 15)
#
# 2021-04-09 16:35:38.173193 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1008.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '2019', '2010', '2020', '1999', '2016', '2008', '2017', '2003', '2015', '2013', '2014', '2006', '2009', '2005', '2011'}
# 2021-04-09 16:39:59.594713 | File complete. DataFrame shape: (1512901, 15)
#
# 2021-04-09 16:40:56.627546 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1007.xml.gz
# 30000 rows found. Years in file: {'2014', '2007', '2006', '2013', '2016', '2008', None, '2021', '2018', '2017', '2019', '2020', '2005', '2015'}
# 2021-04-09 16:45:25.444820 | File complete. DataFrame shape: (1541511, 15)
#
# 2021-04-09 16:46:23.918537 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1006.xml.gz
# 30000 rows found. Years in file: {'2002', None, '2021', '2018', '2000', '2019', '1983', '2010', '2020', '1999', '1988', '2007', '2016', '2017', '2003', '2015', '2013', '1998', '1987', '1997', '2006', '1996', '2009', '2004'}
# 2021-04-09 16:50:42.836242 | File complete. DataFrame shape: (1570064, 15)
#
# 2021-04-09 16:51:41.605873 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1005.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2013', '2008', '2016', None, '2021', '2018', '2001', '2017', '2009', '2019', '2000', '2010', '2020', '2015', '2011'}
# 2021-04-09 16:56:09.704785 | File complete. DataFrame shape: (1598596, 15)
#
# 2021-04-09 16:57:10.979031 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1004.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2008', '2013', '2016', '1988', None, '2021', '1984', '2018', '2000', '2017', '2019', '2009', '2020', '1999', '2015'}
# 2021-04-09 17:01:37.847047 | File complete. DataFrame shape: (1627052, 15)
#
# 2021-04-09 17:02:40.331582 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1003.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '2019', '2010', '2020', '2007', '2016', '2008', '2017', '2003', '2015', '2013', '1993', '2014', '2006', '1996', '2009', '2005', '2004', '2011'}
# 2021-04-09 17:07:00.407542 | File complete. DataFrame shape: (1655521, 15)
#
# 2021-04-09 17:08:00.889035 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1002.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2008', '2013', None, '2021', '2018', '2017', '2009', '2019', '1983', '1998', '2020', '2005', '1999', '2015'}
# 2021-04-09 17:12:17.113052 | File complete. DataFrame shape: (1683559, 15)
#
# 2021-04-09 17:13:18.725177 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1001.xml.gz
# 30000 rows found. Years in file: {'2014', '2007', '2012', '2013', '2016', '2008', None, '2021', '2018', '2001', '2017', '2019', '2020', '2015', '2011'}
# 2021-04-09 17:17:40.357208 | File complete. DataFrame shape: (1712353, 15)
#
# 2021-04-09 17:18:46.104231 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n1000.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2016', '2013', None, '2021', '2018', '1982', '2017', '2019', '1998', '2020', '2015', '2011'}
# 2021-04-09 17:23:09.027214 | File complete. DataFrame shape: (1740993, 15)
#
# 2021-04-09 17:24:15.159109 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0999.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', None, '2021', '2018', '2017', '2019', '2020', '2005', '2015'}
# 2021-04-09 17:28:43.288098 | File complete. DataFrame shape: (1769591, 15)
#
# 2021-04-09 17:29:48.443485 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0998.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', None, '2021', '2018', '2017', '1993', '2019', '2010', '2003', '2020', '1991', '2015', '2011'}
# 2021-04-09 17:34:08.218445 | File complete. DataFrame shape: (1798135, 15)
#
# 2021-04-09 17:35:14.220271 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0997.xml.gz
# 30000 rows found. Years in file: {'2014', '2007', '2002', '2016', '2012', None, '2021', '2018', '2001', '2017', '2019', '2010', '2020', '2005', '2015', '2011'}
# 2021-04-09 17:39:36.989362 | File complete. DataFrame shape: (1826773, 15)
#
# 2021-04-09 17:40:44.495282 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0996.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '1985', '2016', '2008', '2013', None, '2021', '2018', '2017', '2009', '2019', '2020', '2015'}
# 2021-04-09 17:45:06.109051 | File complete. DataFrame shape: (1855300, 15)
#
# 2021-04-09 17:46:16.251871 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0995.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0995.xml.gz
# Error -3 while decompressing data: invalid distance code
# 2021-04-09 17:46:16.323841 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0994.xml.gz
# 30000 rows found. Years in file: {'2014', '1997', '2012', '2016', '2013', None, '2021', '2018', '2017', '2019', '2020', '2015', '2011'}
# 2021-04-09 17:50:43.070952 | File complete. DataFrame shape: (1883890, 15)
#
# 2021-04-09 17:51:52.584695 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0993.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0993.xml.gz
# Error -3 while decompressing data: invalid block type
# 2021-04-09 17:51:52.654699 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0992.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', None, '2021', '1996', '2018', '1982', '2017', '1995', '2019', '2020', '1991', '2015'}
# 2021-04-09 17:56:06.033988 | File complete. DataFrame shape: (1911689, 15)
#
# 2021-04-09 17:57:17.546634 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0991.xml.gz
# 30000 rows found. Years in file: {'2012', '2016', '2008', '2013', None, '2021', '2018', '1995', '2017', '1993', '2019', '2009', '2020', '1994', '1999', '2015'}
# 2021-04-09 18:01:48.490602 | File complete. DataFrame shape: (1939969, 15)
#
# 2021-04-09 18:03:00.374855 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0990.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2013', '2016', '2008', None, '2021', '2018', '1963', '2017', '2009', '2019', '1993', '1992', '2020', '2005', '2015', '2011'}
# 2021-04-09 18:07:14.985633 | File complete. DataFrame shape: (1967833, 15)
#
# 2021-04-09 18:08:24.525009 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0989.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2016', '2008', '2013', None, '2021', '2018', '2009', '2017', '2019', '2010', '1992', '2020', '1991', '2015', '2011'}
# 2021-04-09 18:12:32.277709 | File complete. DataFrame shape: (1995625, 15)
#
# 2021-04-09 18:13:42.321936 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0988.xml.gz
# 30000 rows found. Years in file: {'2012', '1997', '2006', '2016', '2013', '2008', None, '2021', '2018', '2017', '1967', '2019', '1990', '2009', '2020', '2004', '2015', '2011'}
# 2021-04-09 18:17:41.151557 | File complete. DataFrame shape: (2023525, 15)
#
# 2021-04-09 18:18:51.776619 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0987.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '1997', '2013', '1989', '2016', None, '2021', '2015', '2018', '1982', '2017', '2009', '2019', '1990', '2020', '1988', '2011'}
# 2021-04-09 18:23:04.287736 | File complete. DataFrame shape: (2051203, 15)
#
# 2021-04-09 18:24:15.949900 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0986.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0986.xml.gz
# CRC check failed 0x944ad966 != 0xfc8ce299
# 2021-04-09 18:24:17.222901 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0985.xml.gz
# 30000 rows found. Years in file: {'2014', '1985', '2012', '2016', '1984', '2013', '2006', None, '2021', '1996', '2018', '2017', '2009', '2019', '2010', '2020', '2005', '2015'}
# 2021-04-09 18:28:29.548854 | File complete. DataFrame shape: (2079515, 15)
#
# 2021-04-09 18:29:42.552770 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0984.xml.gz
# 30000 rows found. Years in file: {'2002', None, '2021', '2018', '1982', '2019', '1983', '2020', '2016', '2017', '2015', '2013', '1984', '2014', '1997', '2006', '1996', '2001', '2009', '2011'}
# 2021-04-09 18:33:46.017470 | File complete. DataFrame shape: (2107809, 15)
#
# 2021-04-09 18:35:00.071131 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0983.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '1982', '2019', '2010', '2020', '1999', '2007', '2016', '2017', '2003', '2015', '2013', '2014', '1997', '2001', '2009', '2011'}
# 2021-04-09 18:39:19.388515 | File complete. DataFrame shape: (2135909, 15)
#
# 2021-04-09 18:40:33.973890 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0982.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '2000', '2019', '2010', '2020', '1999', '2016', '2017', '1991', '2015', '2013', '1998', '1980', '2014', '1997', '1981', '2011'}
# 2021-04-09 18:44:40.796644 | File complete. DataFrame shape: (2163056, 15)
#
# 2021-04-09 18:45:56.282790 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0981.xml.gz
# 30000 rows found. Years in file: {'2002', None, '2021', '2018', '2000', '2019', '2020', '2016', '2017', '2003', '2015', '1978', '1979', '1998', '1980', '2014', '2001', '2004', '2011'}
# 2021-04-09 18:49:57.721373 | File complete. DataFrame shape: (2189371, 15)
#
# 2021-04-09 18:51:14.459373 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0980.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '2019', '2010', '2020', '2007', '2016', '2008', '2017', '2003', '2015', '2013', '1978', '1979', '2014', '2006', '2009', '2005', '2004', '2011'}
# 2021-04-09 18:55:20.448436 | File complete. DataFrame shape: (2215378, 15)
#
# 2021-04-09 18:56:38.565598 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0979.xml.gz
# 30000 rows found. Years in file: {'1893', '2000', '1852', '2010', '2007', '1885', '1858', '1867', '1864', '1871', '1844', '1868', '1854', '1872', '1839', '1840', '1842', '1876', '1859', '1881', None, '1879', '1851', '1870', '2008', '2016', '1853', '1856', '2013', '1877', '1846', '1904', '1873', '1882', '1849', '2001', '2009', '1875', '1850', '1860', '2011', '1889', '2012', '1890', '2019', '1847', '2020', '1884', '1900', '1886', '1888', '1894', '1883', '1880', '1896', '1848', '1895', '1841', '1843', '1892', '1898', '1857', '2018', '1855', '1878', '1999', '1874', '1897', '1865', '2017', '1906', '2015', '1887', '1899', '1869', '1998', '1845', '2014', '2006', '1907', '1891'}
# 2021-04-09 19:00:08.457389 | File complete. DataFrame shape: (2235506, 15)
#
# 2021-04-09 19:01:27.137707 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0978.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2021', '2018', '2019', '2010', '2020', '1999', '2007', '2016', '2017', '2015', '2013', '1998', '2014', '1997', '1977', '2009', '2005', '2011'}
# 2021-04-09 19:05:28.029042 | File complete. DataFrame shape: (2261535, 15)
#
# 2021-04-09 19:06:46.672462 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0977.xml.gz
# 30000 rows found. Years in file: {'2014', '2007', '2012', '2016', '2008', '2013', None, '2021', '2018', '2017', '2009', '2019', '2010', '2020', '1999', '2015', '2011'}
# 2021-04-09 19:10:47.237540 | File complete. DataFrame shape: (2288077, 15)
#
# 2021-04-09 19:12:07.523387 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0976.xml.gz
# 30000 rows found. Years in file: {'1985', '1971', None, '2021', '2018', '1982', '1967', '1975', '2019', '1983', '1990', '1992', '2000', '2020', '1988', '2016', '1986', '2017', '1970', '1991', '1966', '1972', '2015', '1976', '1984', '1978', '1968', '1979', '1993', '1987', '1980', '2014', '1989', '1977', '1973', '2005', '1969', '1981', '2011', '1974'}
# 2021-04-09 19:16:20.910589 | File complete. DataFrame shape: (2316171, 15)
#
# 2021-04-09 19:17:41.673485 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0975.xml.gz
# 30000 rows found. Years in file: {'2014', '2016', '2008', None, '2021', '2018', '2017', '2009', '2019', '2010', '2000', '1998', '2020', '2004', '2015', '2011'}
# 2021-04-09 19:21:47.520263 | File complete. DataFrame shape: (2343366, 15)
#
# 2021-04-09 19:23:09.808385 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0974.xml.gz
# 30000 rows found. Years in file: {'2014', '2016', '2008', '2013', None, '2018', '2017', '2019', '2010', '2020', '2015', '1976', '2011'}
# 2021-04-09 19:27:21.665869 | File complete. DataFrame shape: (2371063, 15)
#
# 2021-04-09 19:28:45.027687 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0973.xml.gz
# 30000 rows found. Years in file: {'2014', '2016', None, '1996', '2018', '2017', '2019', '2020', '2015'}
# 2021-04-09 19:33:00.839197 | File complete. DataFrame shape: (2399244, 15)
#
# 2021-04-09 19:34:25.274999 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0972.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2006', '2013', '2016', '2008', '2007', None, '2018', '2017', '2000', '2019', '2010', '2009', '2020', '2015', '2011'}
# 2021-04-09 19:38:38.999268 | File complete. DataFrame shape: (2426278, 15)
#
# 2021-04-09 19:40:04.165592 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0971.xml.gz
# 30000 rows found. Years in file: {'2012', '1997', '2014', '2016', '2013', None, '2018', '2017', '2019', '2010', '1998', '2020', '1994', '2004', '2015', '2011'}
# 2021-04-09 19:44:07.070447 | File complete. DataFrame shape: (2453641, 15)
#
# 2021-04-09 19:45:32.993423 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0970.xml.gz
# 30000 rows found. Years in file: {'1800', '1823', '2012', '1810', None, '1830', '2018', '2000', '2019', '2020', '1807', '1999', '1806', '1799', '1812', '1808', '1820', '2016', '2008', '1833', '2017', '1815', '2015', '1821', '1817', '1818', '1805', '1813', '1822', '1829', '1819', '1824', '1828', '2014', '1802', '1826', '1827', '1809', '1814', '1804', '1801', '2009', '1811', '1816', '1831', '1832', '1803', '1825'}
# 2021-04-09 19:49:02.875439 | File complete. DataFrame shape: (2475726, 15)
#
# 2021-04-09 19:50:29.436106 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0969.xml.gz
# 30000 rows found. Years in file: {'2012', '1935', '2002', '1941', '1927', '1948', None, '1924', '2018', '1951', '2000', '1943', '2019', '2020', '1923', '1954', '1933', '1928', '1953', '1925', '1930', '1908', '1950', '1955', '2016', '1906', '2017', '1945', '2003', '1905', '1922', '1936', '2015', '2013', '1946', '1909', '1902', '1942', '1932', '1931', '1998', '1947', '1952', '1944', '1949', '1896', '2014', '1937', '1934', '2006', '1926', '1929', '2001', '1907', '2009', '2004', '1910'}
# 2021-04-09 19:54:21.151375 | File complete. DataFrame shape: (2501497, 15)
#
# 2021-04-09 19:55:51.598945 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0968.xml.gz
# 30000 rows found. Years in file: {'1893', '1921', '1867', '1885', '1858', '1913', '1905', '1864', '1871', '1902', '1868', '1854', '1831', '1872', '1832', '1876', '1859', '1881', None, '1830', '1879', '1870', '2016', '2008', '1853', '1922', '1856', '1912', '1877', '1904', '1873', '1882', '1916', '2001', '1911', '1875', '1918', '1915', '1919', '1860', '2011', '1889', '1862', '1890', '1938', '2019', '2020', '1923', '1884', '1900', '1886', '1939', '1888', '1894', '1883', '1880', '1896', '1996', '1903', '1895', '1861', '1920', '1892', '1898', '1857', '2018', '1940', '1855', '1878', '1999', '1874', '1914', '1866', '1897', '1863', '1865', '2017', '2015', '1887', '1901', '1917', '1899', '1869', '1998', '1829', '1828', '2014', '1997', '2006', '1891'}
# 2021-04-09 19:59:42.296653 | File complete. DataFrame shape: (2524684, 15)
#
# 2021-04-09 20:01:13.826163 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0967.xml.gz
# 30000 rows found. Years in file: {'2012', '1857', '1971', '1859', '2002', None, '2018', '1855', '2000', '2019', '2020', '1999', '2016', '1858', '1833', '1995', '2017', '2003', '1856', '1991', '1834', '2015', '2013', '1998', '2014', '1997', '1996', '2001', '2009', '1835', '2011'}
# 2021-04-09 20:05:25.633822 | File complete. DataFrame shape: (2551644, 15)
#
# 2021-04-09 20:06:57.444682 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0966.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', '1971', None, '2018', '2019', '2010', '1992', '2020', '1999', '2007', '2016', '2008', '2017', '1991', '1972', '2015', '2013', '1993', '2014', '1973'}
# 2021-04-09 20:11:15.540382 | File complete. DataFrame shape: (2579038, 15)
#
# 2021-04-09 20:12:48.569746 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0965.xml.gz
# 30000 rows found. Years in file: {'2012', '1823', '1810', None, '1830', '2018', '1851', '1855', '1837', '2019', '2010', '1852', '1992', '1847', '2020', '1807', '1999', '1806', '1812', '1808', '1838', '1820', '2008', '2016', '1833', '1853', '1995', '2017', '2003', '1815', '1834', '2015', '1821', '1840', '2013', '1817', '1818', '1805', '1846', '1813', '1844', '1836', '1829', '1822', '1998', '1845', '1842', '1824', '1828', '1819', '2014', '1826', '1827', '1848', '1809', '1849', '1854', '1814', '1997', '1996', '2009', '1811', '1831', '1835', '1816', '1832', '1841', '1973', '1850', '1839', '1843', '1825', '2011', '1974'}
# 2021-04-09 20:16:51.840492 | File complete. DataFrame shape: (2604504, 15)
#
# 2021-04-09 20:18:26.052939 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0964.xml.gz
# 30000 rows found. Years in file: {'1800', '2012', '2002', None, '2018', '1975', '2000', '2019', '2010', '1992', '2020', '1799', '2007', '2016', '2008', '1995', '2017', '2003', '1798', '1797', '1991', '2015', '1976', '2013', '1993', '1796', '2014', '1802', '2006', '1804', '1801', '2001', '2005', '2004', '2011'}
# 2021-04-09 20:22:27.932682 | File complete. DataFrame shape: (2631854, 15)
#
# 2021-04-09 20:24:02.666903 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0963.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0963.xml.gz
# Error -3 while decompressing data: invalid stored block lengths
# 2021-04-09 20:24:02.736903 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0962.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', None, '1977', '2018', '2001', '1978', '2017', '2019', '1979', '2010', '1993', '2020', '2004', '2015', '2011'}
# 2021-04-09 20:28:20.364682 | File complete. DataFrame shape: (2659051, 15)
#
# 2021-04-09 20:29:56.277410 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0961.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '1997', '2016', '2013', '2008', '2006', None, '2018', '2017', '2009', '2019', '2010', '1979', '2000', '2020', '2015', '2011'}
# 2021-04-09 20:34:11.752138 | File complete. DataFrame shape: (2686501, 15)
#
# 2021-04-09 20:35:48.013367 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0960.xml.gz
# 30000 rows found. Years in file: {'1857', '1859', '1862', None, '2018', '1855', '1851', '1837', '1852', '2019', '2010', '1847', '2020', '1874', '1870', '1866', '1838', '1867', '1858', '2016', '1853', '1863', '1865', '2017', '1856', '2015', '1839', '1840', '1864', '2011', '2013', '1877', '1871', '1846', '1979', '1869', '1844', '1836', '1868', '1987', '1845', '1873', '2014', '1848', '1980', '1849', '1854', '2009', '1875', '1872', '1841', '1850', '1842', '1843', '1860', '1861', '1876'}
# 2021-04-09 20:39:41.531186 | File complete. DataFrame shape: (2709870, 15)
#
# 2021-04-09 20:41:19.232211 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0959.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2018', '1975', '2000', '2019', '1983', '1990', '1992', '2010', '2020', '1988', '2016', '1986', '2017', '2015', '2013', '1993', '1836', '1980', '2014', '1997', '2001', '2009', '2005', '2004', '1981', '2011'}
# 2021-04-09 20:45:34.648906 | File complete. DataFrame shape: (2736429, 15)
#
# 2021-04-09 20:47:12.851416 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0958.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2013', '2016', None, '2018', '1982', '2017', '2019', '2010', '2020', '1981', '2015'}
# 2021-04-09 20:51:24.429073 | File complete. DataFrame shape: (2764263, 15)
#
# 2021-04-09 20:53:03.737013 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0957.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', None, '2018', '1982', '2017', '2019', '1983', '2020', '2015', '2011'}
# 2021-04-09 20:57:16.845926 | File complete. DataFrame shape: (2791761, 15)
#
# 2021-04-09 20:58:58.376509 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0956.xml.gz
# 30000 rows found. Years in file: {'2012', '2014', '2007', '2016', '1984', '1988', '2013', None, '2018', '2017', '2009', '2019', '1983', '2020', '2015', '2011'}
# 2021-04-09 21:03:14.529354 | File complete. DataFrame shape: (2818859, 15)
#
# 2021-04-09 21:04:56.001186 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0955.xml.gz
# 30000 rows found. Years in file: {'2012', '1985', None, '2018', '2019', '2010', '2020', '2007', '2016', '2008', '2017', '2003', '2015', '2013', '1984', '2014', '2006', '2009', '2011'}
# 2021-04-09 21:09:06.694939 | File complete. DataFrame shape: (2846170, 15)
#
# 2021-04-09 21:10:48.608272 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0954.xml.gz
# 30000 rows found. Years in file: {'2012', '1985', None, '2018', '2000', '1967', '2019', '1983', '2010', '2020', '2016', '2017', '2015', '2013', '2014', '1997', '2006', '2004', '2011'}
# 2021-04-09 21:15:00.632161 | File complete. DataFrame shape: (2873843, 15)
#
# 2021-04-09 21:16:43.961631 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0953.xml.gz
# 30000 rows found. Years in file: {'2012', '1985', '2002', None, '2018', '2019', '2010', '2020', '2007', '2016', '1986', '1995', '2017', '2015', '2013', '2014', '1996', '2001', '2009', '2005', '2011'}
# 2021-04-09 21:20:58.963440 | File complete. DataFrame shape: (2900271, 15)
#
# 2021-04-09 21:22:42.941712 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0952.xml.gz
# 30000 rows found. Years in file: {'1823', '2012', None, '1830', '2018', '2000', '1837', '2019', '1847', '2020', '1999', '1838', '1820', '2016', '1986', '1833', '1995', '2017', '2003', '1834', '2015', '1821', '1840', '2013', '1846', '1844', '1836', '1822', '1829', '1987', '1845', '1842', '1828', '1824', '1826', '2014', '1827', '1835', '1831', '1832', '1841', '2005', '1839', '1843', '1825', '2011'}
# 2021-04-09 21:26:47.923670 | File complete. DataFrame shape: (2924706, 15)
#
# 2021-04-09 21:28:31.688883 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0951.xml.gz
# 30000 rows found. Years in file: {'2014', '2012', '2016', '2013', '1988', None, '2018', '2017', '2019', '2003', '2010', '2020', '2005', '1987', '2015', '2011'}
# 2021-04-09 21:32:33.404082 | File complete. DataFrame shape: (2950939, 15)
#
# 2021-04-09 21:34:16.767020 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0950.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2018', '2000', '2019', '1990', '2010', '1992', '2020', '1999', '1988', '2007', '2016', '1995', '2017', '1991', '1972', '2015', '2013', '1993', '2014', '2006', '1989', '2009', '2005', '1994', '2004', '2011'}
# 2021-04-09 21:38:38.103984 | File complete. DataFrame shape: (2977503, 15)
#
# 2021-04-09 21:40:22.196918 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0949.xml.gz
# 30000 rows found. Years in file: {'1893', '1892', '1898', '1889', None, '1890', '2018', '2019', '1921', '2020', '1999', '1914', '1900', '1897', '2016', '1908', '1886', '1906', '2017', '1913', '1888', '2015', '1887', '1912', '1917', '1894', '1899', '2013', '1909', '1902', '1998', '1904', '1896', '2014', '1997', '1996', '1916', '1903', '1911', '1907', '1895', '1918', '1915', '1891', '1919', '2005', '1920', '1910'}
# 2021-04-09 21:42:50.273593 | File complete. DataFrame shape: (2987363, 15)
#
# 2021-04-09 21:44:34.594542 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0948.xml.gz
# 30000 rows found. Years in file: {'1889', '2012', '1898', None, '1890', '2018', '2019', '2010', '2020', '1900', '1914', '2016', '1908', '1906', '2017', '1913', '1888', '1905', '2015', '1887', '1912', '1901', '2013', '1899', '1909', '1902', '1904', '2014', '2006', '1916', '1903', '1911', '1907', '1895', '1915', '1891', '2011', '1910'}
# 2021-04-09 21:47:22.075699 | File complete. DataFrame shape: (3001588, 15)
#
# 2021-04-09 21:49:07.146723 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0947.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2018', '2019', '2010', '2020', '2007', '2016', '2008', '2017', '2015', '2013', '1979', '2014', '2006', '2009', '2005', '2004', '2011'}
# 2021-04-09 21:53:13.218055 | File complete. DataFrame shape: (3027817, 15)
#
# 2021-04-09 21:54:59.703059 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0946.xml.gz
# 30000 rows found. Years in file: {'2012', '2007', '2006', '2016', '2008', '2014', '2013', None, '1977', '2018', '2017', '2019', '2010', '1998', '2020', '2015', '2011'}
# 2021-04-09 21:59:05.560319 | File complete. DataFrame shape: (3054099, 15)
#
# 2021-04-09 22:00:52.706331 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0945.xml.gz
# 30000 rows found. Years in file: {'2012', None, '2018', '2000', '2019', '2010', '1992', '2020', '1999', '2016', '2008', '1995', '2017', '2003', '2015', '2013', '1998', '1987', '2014', '2001', '2011'}
# 2021-04-09 22:05:01.533847 | File complete. DataFrame shape: (3080116, 15)
#
# 2021-04-09 22:06:50.121886 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0944.xml.gz
# 30000 rows found. Years in file: {'2012', '2002', None, '2018', '1855', '2019', '2010', '2020', '2007', '2016', '2008', '2017', '2003', '2015', '2013', '1984', '2014', '1997', '2006', '1989', '1996', '2009', '1994', '2005', '2004', '2011'}
# 2021-04-09 22:10:56.358245 | File complete. DataFrame shape: (3107055, 15)
#
# 2021-04-09 22:12:45.432226 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0943.xml.gz
# 30000 rows found. Years in file: {'2012', '1857', '2002', '1935', '1941', '1859', '1862', None, '1881', '1879', '2018', '1938', '1855', '1940', '1924', '2019', '1990', '1878', '2010', '2020', '1933', '1928', '1999', '1866', '1925', '2007', '1867', '2016', '1858', '1930', '2008', '1995', '2017', '1865', '2003', '1939', '1922', '1856', '1936', '2015', '2011', '1864', '2013', '1877', '1942', '1932', '1998', '1949', '1883', '1880', '1873', '2014', '1997', '2006', '1934', '1882', '1937', '1926', '1989', '1977', '2001', '2009', '2005', '2004', '1860', '1861', '1876'}
# 2021-04-09 22:16:37.830069 | File complete. DataFrame shape: (3130742, 15)
#
# 2021-04-09 22:18:27.471062 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0942.xml.gz
# 30000 rows found. Years in file: {'1893', '2010', '1885', '2007', '1867', '1913', '1905', '1936', '1871', '1902', '1932', '1868', '1934', '1929', '1872', '1876', '1859', '1881', None, '1924', '1879', '1928', '1870', '1925', '2016', '2008', '1922', '1912', '2013', '1877', '1904', '1873', '1882', '1926', '1911', '2009', '1875', '1860', '1889', '2012', '1927', '1890', '1938', '2019', '2020', '1923', '1933', '1884', '1900', '1886', '1939', '1888', '1894', '1993', '1883', '1896', '1880', '1903', '1895', '1920', '1910', '1892', '1898', '1935', '2018', '1878', '1874', '1914', '1897', '1930', '1908', '1906', '2017', '2015', '1887', '1901', '1899', '1909', '1931', '1869', '1998', '2014', '1937', '2006', '1907', '1891'}
# 2021-04-09 22:22:18.142125 | File complete. DataFrame shape: (3154223, 15)
#
# 2021-04-09 22:24:09.259115 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0941.xml.gz
# ...
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.457407 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0092.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0092.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.459441 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0091.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0091.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.463398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0090.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0090.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.466429 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0089.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0089.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.468448 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0088.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0088.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.471425 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0087.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0087.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.474425 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0086.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0086.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.479398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0085.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0085.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.483397 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0084.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0084.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.486398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0083.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0083.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.492398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0082.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0082.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.493443 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0081.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0081.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.496437 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0080.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0080.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.501441 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0079.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0079.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.505426 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0078.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0078.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.508398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0077.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0077.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.515397 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0076.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0076.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.518458 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0075.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0075.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.522440 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0074.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0074.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.526443 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0073.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0073.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.530449 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0072.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0072.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.533441 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0071.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0071.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.537423 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0070.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0070.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.541446 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0069.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0069.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.544439 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0068.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0068.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.547398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0067.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0067.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.551410 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0066.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0066.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.554426 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0065.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0065.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.557426 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0064.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0064.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.559435 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0063.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0063.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.563398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0062.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0062.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.567429 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0061.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0061.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.572430 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0060.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0060.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.576398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0059.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0059.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.579429 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0058.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0058.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.582435 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0057.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0057.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.585407 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0056.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0056.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.587442 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0055.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0055.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.592432 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0054.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0054.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.597432 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0053.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0053.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.603398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0052.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0052.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.607429 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0051.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0051.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.610432 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0050.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0050.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.615434 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0049.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0049.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.619432 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0048.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0048.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.621450 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0047.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0047.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.623398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0046.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0046.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.627430 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0045.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0045.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.630443 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0044.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0044.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.633432 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0043.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0043.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.638451 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0042.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0042.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.642432 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0041.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0041.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.645398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0040.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0040.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.650431 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0039.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0039.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.652398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0038.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0038.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.655430 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0037.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0037.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.658398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0036.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0036.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.661451 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0035.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0035.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.664431 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0034.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0034.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.666449 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0033.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0033.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.670431 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0032.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0032.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.674432 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0031.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0031.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.676430 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0030.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0030.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.678458 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0029.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0029.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.683441 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0028.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0028.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.687398 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0027.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0027.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.691425 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0026.xml.gz
# Failure for  C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0026.xml.gz
# [Errno 22] Invalid argument
# 2021-04-10 11:43:35.695434 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0025.xml.gz
# 30000 rows found. Years in file: {None, '1977', '1979', '1978'}
# 2021-04-10 11:45:53.899330 | File complete. DataFrame shape: (3579099, 15)
#
# BREAKING loop - fewer than 500 rows found in last file.
# 2021-04-10 11:47:59.638012 | Processing: C:\Users\aday\OneDrive - SAGE Publishing\DATA\PubMed\pubmed21n0024.xml.gz
# Breaking loop - we are no longer looking at our years of interest.
# (3579099, 15)

# %%
df.head()
# Out:
#                                          title  \
# 0  International journal of molecular sciences
# 1        Journal of fungi (Basel, Switzerland)
# 2   Animals : an open access journal from MDPI
# 3                                Micromachines
# 4  International journal of molecular sciences
#
#                                         articletitle  \
# 0  Insight into Cisplatin-Resistance Signaling of...
# 1  Rye Snow Mold-Associated Microdochium nivale S...
# 2  Feeding Tall Fescue Seed Reduces Ewe Milk Prod...
# 3  Composites, Fabrication and Application of Pol...
# 4  Comparison of Bisulfite Pyrosequencing and Met...
#
#                                             abstract  year articledate  \
# 0  The microenvironment possesses a strong impact...  2020  2020-12-03
# 1  Snow mold is a severe plant disease caused by ...  2020  2020-12-03
# 2  Endophyte-infected tall fescue (E+) produces e...  2020  2020-12-03
# 3  The technological development of piezoelectric...  2020  2020-12-03
# 4  Different methodological approaches are availa...  2020  2020-12-03
#
#                     doi      pmid           pii         pmc  \
# 0  10.3390/ijms21239240  33287446  ijms21239240  PMC7730285
# 1    10.3390/jof6040335  33287447    jof6040335        None
# 2   10.3390/ani10122291  33287449   ani10122291        None
# 3    10.3390/mi11121076  33287450    mi11121076        None
# 4  10.3390/ijms21239242  33287451  ijms21239242  PMC7730915
#
#               articletype1    articletype2 articletype3  \
# 0  D016428|Journal Article            None         None
# 1  D016428|Journal Article            None         None
# 2  D016428|Journal Article            None         None
# 3  D016428|Journal Article  D016454|Review         None
# 4  D016428|Journal Article            None         None
#
#                                  journal_title journal_issn  \
# 0  International journal of molecular sciences    1422-0067
# 1        Journal of fungi (Basel, Switzerland)    2309-608X
# 2   Animals : an open access journal from MDPI    2076-2615
# 3                                Micromachines    2072-666X
# 4  International journal of molecular sciences    1422-0067
#
#              journal_iso
# 0          Int J Mol Sci
# 1        J Fungi (Basel)
# 2        Animals (Basel)
# 3  Micromachines (Basel)
# 4          Int J Mol Sci

# %% [markdown]
# # Filter out non-research / case report article types

# %%
df.articletype1.value_counts().head(10)
# Out:
# D016428|Journal Article      3067435
# D002363|Case Reports          151047
# D016422|Letter                107331
# D016421|Editorial              85085
# D003160|Comparative Study      61925
# D016425|Published Erratum      18568
# D023362|Evaluation Study       15425
# D016430|Clinical Trial         13324
# D016433|News                   12688
# D004740|English Abstract        8608
# Name: articletype1, dtype: int64

# %%
df.articletype2.value_counts().head(10)
# Out:
# D013485|Research Support, Non-U.S. Gov't        540791
# D016454|Review                                  249295
# D016428|Journal Article                         196838
# D052061|Research Support, N.I.H., Extramural    156470
# D016420|Comment                                 114902
# D016448|Multicenter Study                        30291
# D016449|Randomized Controlled Trial              30119
# D017418|Meta-Analysis                            27762
# D064888|Observational Study                      25378
# D016425|Published Erratum                        24147
# Name: articletype2, dtype: int64

# %%
df.articletype3.value_counts().head(10)
# Out:
# D013485|Research Support, Non-U.S. Gov't            150792
# D016454|Review                                       60521
# D013486|Research Support, U.S. Gov't, Non-P.H.S.     29170
# D052061|Research Support, N.I.H., Extramural         24735
# D000078182|Systematic Review                         18972
# D016449|Randomized Controlled Trial                  12215
# D016448|Multicenter Study                            10992
# D016420|Comment                                       8928
# D016428|Journal Article                               8285
# D064888|Observational Study                           8030
# Name: articletype3, dtype: int64

# %% [markdown]
# Given the above, it looks like the first article-type is the main one. We will use this to separate case-reports and regular journal articles. For now, we will ignore other article types.

# %%
# dfout = df[df['articletype1'].isin({'D016428|Journal Article','D002363|Case Reports'})]
# dfout.shape

# %% [markdown]
# ## Write-out

# %%
df_path = os.path.join(working_data_path,'pubmed_sample.csv')
df.to_csv(df_path, index=False, encoding = 'utf-8-sig')
